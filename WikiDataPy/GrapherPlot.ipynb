# %%
import networkx as nx
import matplotlib.pyplot as plt
from reader import WikiReader
from pprint import pprint
from grapher import WikiGraph
from matplotlib import pyplot as plt

# %%
g = WikiGraph("Q5")
# g.buildGraph(r=3)
g.r
# Out:
# 0

# %%
g2 = WikiGraph("Q1058")
g2.buildGraph()

# %%
g = WikiGraph("Q1058")

g.buildGraph(r=2) #6s
g.plotNamedGraph()

# %%
g.buildGraph(r=3) #17.3s + 1.6s

# %%
g.plotNamedGraph()

# %%
g2 = WikiGraph("Q1058")
g2.buildGraph(r=3)

# %%
g2.plotNamedGraph()

# %% [markdown]
# ## Ratan tata knowledge graph

# %%
ratan_qid = "Q333460"
ratanG = WikiGraph(ratan_qid)
ratanG.buildGraph(r=2,out_degree=4)

# %%
ratanG.plotNamedGraph("../plots/demo/ratanTataKnowledge_2.png")

# %% [markdown]
# ## Elon knowledge graph

# %%
elon_qid = "Q317521"
elonG = WikiGraph(elon_qid)
elonG.buildGraph(r=3,out_degree=3)

# %%
elonG.plotNamedGraph()
